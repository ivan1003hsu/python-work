# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel("http://www.ceec.edu.tw/files/file_pool/1/0J240503575697368489/03%E5%90%84%E7%A7%91%E5%90%84%E8%80%83%E5%8D%80%E5%A0%B1%E5%90%8D%E4%BA%BA%E6%95%B8%E7%B8%BD%E8%A1%A8108.xls",names=c_names)

# %%
df.head()
# Out:
#   考區\考科    國文    英文   數學甲   數學乙    化學    物理    生物    歷史    地理  公民與社會    總計
# 0    考科    國文    英文   數學甲   數學乙    化學    物理    生物    歷史    地理  公民與社會    總計
# 1    考區   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 2   臺北一  4271  4447  4127  2564  3928  3742  2945   661   611    597  4475
# 3   臺北二  3513  3569  1326  3009  1201  1119   819  2340  2284   2127  3570
# 4   臺北三  2687  2687    91  2573     0     0     0  2670  2568   2381  2687

# %%
df.drop(1,inplace=True)

# %%
df.head()
# Out:
#   考區\考科    國文    英文   數學甲   數學乙    化學    物理    生物    歷史    地理 公民與社會    總計
# 2   臺北一  4271  4447  4127  2564  3928  3742  2945   661   611   597  4475
# 3   臺北二  3513  3569  1326  3009  1201  1119   819  2340  2284  2127  3570
# 4   臺北三  2687  2687    91  2573     0     0     0  2670  2568  2381  2687
# 5   新北一  4310  4359  2047  3435  1824  1728  1233  2517  2433  2245  4370
# 6   新北二  2609  2655  1273  2060  1130  1041   792  1546  1484  1381  2662

# %%
'臺北' in df['考區\考科']
# Out:
# False

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-accbcb48d69c> in <module>
# ----> 1 df['臺北' in df['考區\考科']]
#
# ...
